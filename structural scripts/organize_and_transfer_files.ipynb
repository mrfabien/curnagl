# %%
# this one creates a new folder if it doesn't exist, and moves the files to the corresponding folder in the destination directory

import os
import re
import shutil

def organize_and_transfer_files(source_dir, destination_dir):
    # Check if both directories exist
    if not os.path.exists(source_dir):
        print(f"Source directory '{source_dir}' does not exist.")
        return
    if not os.path.exists(destination_dir):
        print(f"Destination directory '{destination_dir}' does not exist.")
        return
    
    # Get list of files in the source directory
    files = os.listdir(source_dir)
    
    # Create a dictionary to store files for each variable
    variable_files = {}
    
    # Group files by variable name
    for file in files:
        source_path = os.path.join(source_dir, file)
        # Extract variable name from the file name using regular expression
        match = re.match(r'ERA5_\d+-\d+_(.+)\.nc', file)
        if match:
            variable_name = match.group(1)
            if variable_name not in variable_files:
                variable_files[variable_name] = []
            variable_files[variable_name].append(source_path)
        else:
            print(f"Could not extract variable name from '{file}'")

    # Transfer files for each variable to the corresponding folder in the destination directory
    for variable_name, file_paths in variable_files.items():
        destination_folder = os.path.join(destination_dir, variable_name)
        # Create the variable name folder if it doesn't exist
        if not os.path.exists(destination_folder):
            os.makedirs(destination_folder)
        # Move files to the variable folder
        for file_path in file_paths:
            filename = os.path.basename(file_path)
            destination_path = os.path.join(destination_folder, filename)
            shutil.move(file_path, destination_path)
            print(f"Moved '{filename}' to '{destination_folder}'")


# Example usage:
source_directory = "/work/FAC/FGSE/IDYST/tbeucler/default/fabien/repos/curnagl/missing_var"
destination_directory = "/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL"
organize_and_transfer_files(source_directory, destination_directory)

# %%
# this doesn't create a new folder if it doesn't exist, it just moves the files to the corresponding folder in the destination directory

import os
import re
import shutil

def organize_and_transfer_files(source_dir, destination_dir):
    # Check if both directories exist
    if not os.path.exists(source_dir):
        print(f"Source directory '{source_dir}' does not exist.")
        return
    if not os.path.exists(destination_dir):
        print(f"Destination directory '{destination_dir}' does not exist.")
        return
    
    # Get list of files in the source directory
    files = os.listdir(source_dir)
    
    # Create a dictionary to store files for each variable
    variable_files = {}
    
    # Group files by variable name
    for file in files:
        source_path = os.path.join(source_dir, file)
        # Extract variable name from the file name using regular expression
        match = re.match(r'ERA5_\d+-\d+_(.+)\.nc', file)
        if match:
            variable_name = match.group(1)
            if variable_name not in variable_files:
                variable_files[variable_name] = []
            variable_files[variable_name].append(source_path)
        else:
            print(f"Could not extract variable name from '{file}'")

    # Transfer files for each variable to the corresponding folder in the destination directory
    for variable_name, file_paths in variable_files.items():
        destination_folder = os.path.join(destination_dir, variable_name)
        # Check if the variable name folder exists
        if os.path.exists(destination_folder):
            # Move files to the variable folder
            for file_path in file_paths:
                filename = os.path.basename(file_path)
                destination_path = os.path.join(destination_folder, filename)
                shutil.move(file_path, destination_path)
                print(f"Moved '{filename}' to '{destination_folder}'")
        else:
            print(f"Folder '{variable_name}' does not exist in '{destination_dir}'. Skipping...")

# Example usage:
source_directory = "/work/FAC/FGSE/IDYST/tbeucler/default/fabien/repos/curnagl/missing_var/"
destination_directory = "/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL"
organize_and_transfer_files(source_directory, destination_directory)
# Out:
# Could not extract variable name from 'land_sea_mask'
# Could not extract variable name from 'total_totals_index'
# Could not extract variable name from 'slurm-43272548.out'
# Could not extract variable name from 'high_cloud_cover'
# Could not extract variable name from 'slurm-42990685.out'
# Could not extract variable name from 'missing_variables.csv'
# Could not extract variable name from 'mean_top_net_long_wave_radiation_flux'
# Could not extract variable name from 'mean_sea_level_pressure'
# Could not extract variable name from 'mean_vertically_integrated_moisture_divergence'
# Could not extract variable name from 'missing_var_retrieve.sh'
# Could not extract variable name from 'slurm-42990491.out'
# Could not extract variable name from 'instantaneous_10m_wind_gust'
# Could not extract variable name from 'convective_snowfall'
# Could not extract variable name from 'slurm-43347677.out'
# Could not extract variable name from 'missing_variables_done.csv'
# Could not extract variable name from 'convective_precipitation'
# Could not extract variable name from 'large_scale_snowfall'
# Could not extract variable name from 'large_scale_precipitation'
# Could not extract variable name from 'missing_var_retrieve.py'
# Could not extract variable name from 'slurm-42990338.out'
# Could not extract variable name from 'missing_variables_to_check.csv'
# Could not extract variable name from 'mean_surface_net_short_wave_radiation_flux'
# Could not extract variable name from 'mean_total_precipitation_rate'
# Could not extract variable name from 'mean_surface_net_long_wave_radiation_flux'
# Could not extract variable name from 'slurm-43238465.out'
# Could not extract variable name from 'slurm-43267273.out'
# Could not extract variable name from 'mean_surface_direct_short_wave_radiation_flux'
# Could not extract variable name from 'total_precipitation'
# Could not extract variable name from 'convective_rain_rate'
# Could not extract variable name from 'convective_inhibition'
# Could not extract variable name from 'mean_surface_latent_heat_flux'
# Could not extract variable name from 'k_index'
# Could not extract variable name from 'mean_top_net_short_wave_radiation_flux'
# Could not extract variable name from 'mean_large_scale_precipitation_rate'
# Could not extract variable name from 'cloud_base_height'
# Could not extract variable name from 'slurm-43272606.out'
# Moved 'ERA5_2006-2_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2004-2_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2014-1_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2005-11_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2017-8_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2004-5_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2005-8_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1999-3_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2013-4_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2011-7_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1995-2_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1990-12_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2015-4_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2014-3_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2006-6_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2001-12_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2000-4_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2019-10_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2018-2_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2011-2_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2017-1_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1996-3_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2019-7_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1990-4_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2006-3_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2016-8_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2009-1_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2006-5_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2010-3_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2019-3_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2010-6_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1995-5_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2013-1_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2009-12_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2017-12_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1999-4_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1997-4_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2021-6_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2001-9_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2011-1_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2012-5_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2003-3_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2019-5_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2021-10_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2019-11_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1999-12_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1990-9_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1996-4_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2012-9_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2009-5_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2007-1_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2005-4_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2005-12_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2001-7_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2017-10_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1999-11_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2007-2_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1997-3_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2008-4_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1992-7_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2008-2_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2009-11_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2008-12_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2007-3_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1993-1_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1994-1_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2004-8_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2002-10_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1990-1_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2010-2_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2018-6_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2002-4_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2001-10_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1993-2_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2000-7_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1999-6_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1997-6_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2016-6_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1991-2_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2004-11_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2001-6_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2008-8_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2001-2_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1995-4_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2000-8_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2008-10_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2006-11_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2010-8_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2020-8_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2018-5_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2013-5_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2002-8_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2016-2_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2005-3_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2020-10_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2020-5_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1997-12_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2015-6_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1996-5_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2021-11_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1990-8_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1995-7_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2008-6_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2007-6_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2014-8_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1996-10_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2006-1_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2014-10_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2009-2_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2016-12_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2012-4_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1993-7_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1993-6_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2006-9_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2004-9_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2020-1_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2015-1_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2006-10_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1999-1_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2017-7_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2000-1_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1994-5_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1994-9_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2016-7_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2016-10_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2010-4_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1991-1_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1992-2_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1996-2_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1998-3_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2007-7_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_1996-7_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2014-7_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2009-3_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_2008-3_mean_large_scale_precipitation_rate.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/mean_large_scale_precipitation_rate'
# Moved 'ERA5_