# %%
# this one creates a new folder if it doesn't exist, and moves the files to the corresponding folder in the destination directory

import os
import re
import shutil

def organize_and_transfer_files(source_dir, destination_dir):
    # Check if both directories exist
    if not os.path.exists(source_dir):
        print(f"Source directory '{source_dir}' does not exist.")
        return
    if not os.path.exists(destination_dir):
        print(f"Destination directory '{destination_dir}' does not exist.")
        return
    
    # Get list of files in the source directory
    files = os.listdir(source_dir)
    
    # Create a dictionary to store files for each variable
    variable_files = {}
    
    # Group files by variable name
    for file in files:
        source_path = os.path.join(source_dir, file)
        # Extract variable name from the file name using regular expression
        match = re.match(r'ERA5_\d+-\d+_(.+)\.nc', file)
        if match:
            variable_name = match.group(1)
            if variable_name not in variable_files:
                variable_files[variable_name] = []
            variable_files[variable_name].append(source_path)
        else:
            print(f"Could not extract variable name from '{file}'")

    # Transfer files for each variable to the corresponding folder in the destination directory
    for variable_name, file_paths in variable_files.items():
        destination_folder = os.path.join(destination_dir, variable_name)
        # Create the variable name folder if it doesn't exist
        if not os.path.exists(destination_folder):
            os.makedirs(destination_folder)
        # Move files to the variable folder
        for file_path in file_paths:
            filename = os.path.basename(file_path)
            destination_path = os.path.join(destination_folder, filename)
            shutil.move(file_path, destination_path)
            print(f"Moved '{filename}' to '{destination_folder}'")


# Example usage:
source_directory = "/work/FAC/FGSE/IDYST/tbeucler/default/fabien/repos/curnagl/missing_var"
destination_directory = "/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL"
organize_and_transfer_files(source_directory, destination_directory)

# %%
# this doesn't create a new folder if it doesn't exist, it just moves the files to the corresponding folder in the destination directory

import os
import re
import shutil

def organize_and_transfer_files(source_dir, destination_dir):
    # Check if both directories exist
    if not os.path.exists(source_dir):
        print(f"Source directory '{source_dir}' does not exist.")
        return
    if not os.path.exists(destination_dir):
        print(f"Destination directory '{destination_dir}' does not exist.")
        return
    
    # Get list of files in the source directory
    files = os.listdir(source_dir)
    
    # Create a dictionary to store files for each variable
    variable_files = {}
    
    # Group files by variable name
    for file in files:
        source_path = os.path.join(source_dir, file)
        # Extract variable name from the file name using regular expression
        match = re.match(r'ERA5_\d+-\d+_(.+)\.nc', file)
        if match:
            variable_name = match.group(1)
            if variable_name not in variable_files:
                variable_files[variable_name] = []
            variable_files[variable_name].append(source_path)
        else:
            print(f"Could not extract variable name from '{file}'")

    # Transfer files for each variable to the corresponding folder in the destination directory
    for variable_name, file_paths in variable_files.items():
        destination_folder = os.path.join(destination_dir, variable_name)
        # Check if the variable name folder exists
        if os.path.exists(destination_folder):
            # Move files to the variable folder
            for file_path in file_paths:
                filename = os.path.basename(file_path)
                destination_path = os.path.join(destination_folder, filename)
                shutil.move(file_path, destination_path)
                print(f"Moved '{filename}' to '{destination_folder}'")
        else:
            print(f"Folder '{variable_name}' does not exist in '{destination_dir}'. Skipping...")

# Example usage:
source_directory = "/work/FAC/FGSE/IDYST/tbeucler/default/fabien/repos/curnagl/missing_var/"
destination_directory = "/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL"
organize_and_transfer_files(source_directory, destination_directory)
# Out:
# Could not extract variable name from 'total_totals_index'
# Could not extract variable name from 'slurm-43272548.out'
# Could not extract variable name from 'slurm-42990685.out'
# Could not extract variable name from 'missing_variables.csv'
# Could not extract variable name from 'missing_var_retrieve.sh'
# Could not extract variable name from 'slurm-42990491.out'
# Could not extract variable name from 'instantaneous_10m_wind_gust'
# Could not extract variable name from 'slurm-43347677.out'
# Could not extract variable name from 'slurm-43510331.out'
# Could not extract variable name from 'missing_var_retrieve.py'
# Could not extract variable name from 'slurm-42990338.out'
# Could not extract variable name from 'missing_variables_to_check.csv'
# Could not extract variable name from 'slurm-43614543.out'
# Could not extract variable name from 'slurm-43238465.out'
# Could not extract variable name from 'slurm-43267273.out'
# Could not extract variable name from 'slurm-43612825.out'
# Could not extract variable name from 'convective_inhibition'
# Could not extract variable name from 'slurm-43714313.out'
# Could not extract variable name from 'k_index'
# Could not extract variable name from 'missing_var_retrieve_mslw.py'
# Could not extract variable name from 'slurm-43272606.out'
# Moved 'ERA5_2021-3_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2006-6_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2010-2_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2012-1_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2020-4_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2020-10_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2019-9_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2007-9_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2007-6_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2013-5_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2011-12_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2015-6_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2009-4_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2015-3_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2014-9_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2014-8_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2016-5_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2010-9_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2016-2_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2010-1_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2008-1_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2008-9_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2005-9_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2016-7_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2013-1_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2009-9_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2011-4_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2021-4_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2017-5_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2012-4_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2009-5_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2015-1_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2009-2_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2008-12_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2016-11_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2010-8_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2016-3_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2011-11_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2020-2_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2006-11_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2018-1_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2012-11_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2009-7_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2020-8_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2005-3_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2021-9_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2013-6_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2018-8_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2007-3_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2007-10_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2017-9_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2019-2_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2016-4_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2009-3_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2012-8_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2012-12_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2006-3_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2008-4_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2012-10_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2007-1_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2013-9_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2018-9_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2013-4_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2020-1_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2011-9_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2020-11_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2014-6_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2009-6_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2015-7_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2011-8_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2008-7_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2010-3_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2010-10_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2008-6_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2015-8_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2020-12_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2008-8_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2018-12_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2019-1_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2017-6_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2010-4_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2006-5_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2018-10_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2018-5_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2014-10_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2020-6_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2017-8_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2020-7_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2014-2_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2018-3_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2013-10_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2006-12_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2010-5_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2009-12_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2017-12_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2005-4_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2020-5_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2015-2_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2016-9_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2019-8_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2020-9_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2017-4_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2008-2_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2015-11_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2005-7_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2008-3_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2019-12_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2021-11_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2020-3_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2018-4_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2008-10_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2017-10_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2019-6_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2005-6_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2014-7_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2014-11_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2019-3_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2013-2_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2017-2_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2015-12_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2015-4_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2021-1_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2011-6_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2011-7_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2005-8_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2012-9_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2015-5_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2015-9_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2015-10_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2010-7_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2007-4_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2014-4_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2009-10_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2005-5_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2013-11_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2018-7_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2016-1_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2013-8_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2021-5_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2012-2_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2011-10_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2019-5_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2006-8_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2019-11_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2010-11_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2013-7_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2017-11_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2021-8_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2009-11_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2006-2_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2014-12_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2021-2_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2009-1_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2011-3_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2011-5_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2014-1_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2006-1_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2019-7_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2021-7_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2008-11_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2018-11_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2007-2_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2013-3_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2007-8_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2005-10_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2012-3_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2012-7_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2007-12_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2007-5_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2016-6_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2009-8_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2014-5_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2006-10_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2018-2_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2021-10_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2016-10_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2018-6_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2006-7_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2005-12_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2007-11_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2010-12_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2005-1_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2012-6_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2008-5_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2014-3_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2005-2_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2005-11_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2007-7_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2021-6_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2013-12_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2016-12_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2016-8_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2017-1_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2017-7_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2017-3_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2011-1_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2011-2_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2006-9_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2021-12_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2010-6_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2019-10_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2019-4_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2006-4_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
# Moved 'ERA5_2012-5_total_precipitation.nc' to '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/SL/total_precipitation'
