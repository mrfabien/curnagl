# %%
import xarray as xr
import numpy as np
import pandas as pd

# %%
local_path = '/Users/fabienaugsburger/myCloud/Unil/Master/Thesis/Datasets/Curnagl/ERA5_1990_2m_dewpoint_temperature.nc'
servor_path = '/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/fabien2/ERA5/'

print(servor_path+'2m_dewpoint/')
# Out:
# /work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/fabien2/ERA5/2m_dewpoint/

# %%
# open all the 2dm dewpoint temperature files

#try_0 = xr.open_dataset('/work/FAC/FGSE/IDYST/tbeucler/default/raw_data/ECMWF/ERA5/fabien2/ERA5/2m_dewpoint/ERA5_1990_2m_dewpoint_temperature.nc')

d2m = xr.open_mfdataset(servor_path+'2m_dewpoint/*.nc', combine='by_coords')
d2m
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 1440, latitude: 721, time: 84728)
# Coordinates:
#   * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#   * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#   * time       (time) datetime64[ns] 1990-01-01 ... 2019-12-31T21:00:00
# Data variables:
#     d2m        (time, latitude, longitude) float32 dask.array<chunksize=(2920, 721, 1440), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
# import all tracks

track_dict = {}

for i in range(1, 97):
    # Read the CSV file and store it in the dictionary
    track_dict[f'track_{i-1}'] = pd.read_csv(f'tc_irad_tracks/tc_irad_{i}.txt')

# create a list of all the tracks

track_list = []

for i in range(1, 97):
    track_list.append(track_dict[f'track_{i-1}'])

# %%
# slice the time dimension by storm

storm_data = {}

dates = pd.read_csv('storms_start_end.csv', sep=',')

for i in range(0,96):
    start_first_temp = dates['start_date'][i]
    end_first_temp = dates['end_date'][i]

    d2m_storm_i = d2m.sel(time=slice(start_first_temp, end_first_temp))

    # Store the selected DataArray in the dictionary
    storm_data[f'storm_{i}'] = d2m_storm_i

storm_data
# Out:
# {'storm_0': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 62)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1990-01-21T03:00:00 ... 1990-01-28T18:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(62, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_1': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 52)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1990-01-23T03:00:00 ... 1990-01-29T12:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(52, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_2': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 59)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1990-01-28T18:00:00 ... 1990-02-05
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(59, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_3': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 16)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1990-02-18T12:00:00 ... 1990-02-20T09:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(16, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_4': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 41)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1990-02-23T18:00:00 ... 1990-02-28T18:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(41, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_5': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 76)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1990-02-22T15:00:00 ... 1990-03-04
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(76, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_6': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 43)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1990-02-01 ... 1990-02-06T06:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(43, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_7': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 89)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1991-01-03 ... 1991-01-14
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(89, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_8': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 27)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1991-12-18T18:00:00 ... 1991-12-22
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(27, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_9': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 37)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1991-12-30T21:00:00 ... 1992-01-04T09:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(9, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_10': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 112)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1992-02-24T06:00:00 ... 1992-03-09T03:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(112, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_11': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 49)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1992-12-15T15:00:00 ... 1992-12-21T15:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(49, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_12': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 57)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1992-12-22T21:00:00 ... 1992-12-29T21:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(57, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_13': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 101)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1993-01-04 ... 1993-01-16T12:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(101, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_14': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 57)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1993-01-08 ... 1993-01-15
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(57, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_15': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 68)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1993-01-14T03:00:00 ... 1993-01-22T12:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(68, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_16': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 39)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1993-01-12 ... 1993-01-16T18:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(39, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_17': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 11)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1993-02-02T18:00:00 ... 1993-02-04
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(11, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_18': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 76)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1993-12-03 ... 1993-12-12T09:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(76, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_19': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 43)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1994-01-21T12:00:00 ... 1994-01-26T18:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(43, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_20': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 80)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1994-01-23T06:00:00 ... 1994-02-02T03:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(80, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_21': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 33)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1994-12-07T18:00:00 ... 1994-12-11T18:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(33, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_22': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 26)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1995-01-16T06:00:00 ... 1995-01-19T09:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(26, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_23': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 9)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1995-01-23 ... 1995-01-24
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(9, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_24': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 8)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1995-10-24T03:00:00 ... 1995-10-25
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(8, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_25': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 76)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1996-10-06T09:00:00 ... 1996-10-15T18:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(76, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_26': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 158)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1996-10-12 ... 1996-10-31T15:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(158, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_27': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 53)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1996-11-05T12:00:00 ... 1996-11-12
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(53, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_28': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 70)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1997-02-15T03:00:00 ... 1997-02-23T18:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(70, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_29': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 46)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1997-02-22T09:00:00 ... 1997-02-28
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(46, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_30': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 25)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1997-12-22T18:00:00 ... 1997-12-25T18:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(25, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_31': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 50)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1997-12-31 ... 1998-01-06T03:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(8, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_32': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 45)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1997-12-31T12:00:00 ... 1998-01-06
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(4, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_33': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 47)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1998-12-24 ... 1998-12-29T18:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(47, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_34': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 47)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1999-01-13T12:00:00 ... 1999-01-19T06:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(47, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_35': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 21)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1998-10-27T12:00:00 ... 1998-10-30
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(21, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_36': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 38)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1999-12-02 ... 1999-12-06T15:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(38, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_37': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 21)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1999-12-24 ... 1999-12-26T12:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(21, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_38': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 6)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1999-12-31T06:00:00 ... 1999-12-31T21:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(6, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_39': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 47)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 1999-12-26T03:00:00 ... 1999-12-31T21:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(47, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_40': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 0)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns]
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(0, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_41': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 0)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns]
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(0, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_42': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 41)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2001-12-25T18:00:00 ... 2001-12-30T18:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(41, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_43': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 65)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2002-01-25T15:00:00 ... 2002-02-02T15:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(65, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_44': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 80)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2002-02-21T09:00:00 ... 2002-03-03T06:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(80, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_45': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 63)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2002-10-23T12:00:00 ... 2002-10-31T06:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(63, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_46': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 44)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2005-01-05T18:00:00 ... 2005-01-11T03:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(44, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_47': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 93)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2005-01-07 ... 2005-01-18T12:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(93, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_48': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 95)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2005-11-02 ... 2005-11-13T18:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(95, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_49': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 39)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2005-11-09T03:00:00 ... 2005-11-13T21:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(39, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_50': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 68)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2006-01-08T12:00:00 ... 2006-01-16T21:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(68, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_51': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 42)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2006-12-30 ... 2007-01-04T03:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(16, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_52': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 38)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2007-03-15T12:00:00 ... 2007-03-20T03:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(38, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_53': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 56)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2007-01-14T06:00:00 ... 2007-01-21T03:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(56, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_54': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 38)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2007-11-06T18:00:00 ... 2007-11-11T09:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(38, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_55': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 58)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2007-12-03T15:00:00 ... 2007-12-10T18:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(58, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_56': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 25)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2008-01-07T18:00:00 ... 2008-01-10T18:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(25, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_57': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 59)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2008-01-20T03:00:00 ... 2008-01-27T09:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(59, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_58': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 40)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2008-02-05 ... 2008-02-09T21:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(40, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_59': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 71)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2008-03-07T21:00:00 ... 2008-03-16T15:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(71, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_60': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 63)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2008-02-25 ... 2008-03-03T18:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(63, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_61': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 44)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2008-12-16T06:00:00 ... 2008-12-21T15:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(44, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_62': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 51)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2009-01-13T03:00:00 ... 2009-01-19T09:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(51, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_63': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 46)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2009-01-22 ... 2009-01-27T15:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(46, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_64': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 98)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2010-02-23 ... 2010-03-07T03:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(98, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_65': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 33)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2011-02-01T09:00:00 ... 2011-02-05T09:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(33, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_66': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 45)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2011-11-23 ... 2011-11-28T12:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(45, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_67': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 60)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2011-12-06T15:00:00 ... 2011-12-14
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(60, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_68': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 33)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2011-12-22T21:00:00 ... 2011-12-26T21:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(33, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_69': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 41)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2012-01-02T15:00:00 ... 2012-01-07T15:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(41, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_70': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 34)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2013-10-26T03:00:00 ... 2013-10-30T06:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(34, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_71': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 62)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2013-11-11T21:00:00 ... 2013-11-19T12:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(62, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_72': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 54)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2013-12-02T09:00:00 ... 2013-12-09
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(54, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_73': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 30)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2013-12-12T12:00:00 ... 2013-12-16T03:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(30, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_74': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 50)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2013-12-12T18:00:00 ... 2013-12-18T21:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(50, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_75': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 41)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2013-12-15T15:00:00 ... 2013-12-20T15:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(41, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_76': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 44)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2013-12-10T06:00:00 ... 2013-12-15T15:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(44, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_77': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 62)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2013-12-22T18:00:00 ... 2013-12-30T09:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(62, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_78': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 46)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2014-02-09T09:00:00 ... 2014-02-15
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(46, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_79': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 61)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2015-01-05 ... 2015-01-12T12:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(61, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_80': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 43)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2015-01-05T15:00:00 ... 2015-01-10T21:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(43, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_81': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 44)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2015-01-10T12:00:00 ... 2015-01-15T21:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(44, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_82': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 54)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2015-01-12T18:00:00 ... 2015-01-19T09:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(54, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_83': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 30)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2015-02-06T18:00:00 ... 2015-02-10T09:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(30, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_84': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 37)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2016-01-27T15:00:00 ... 2016-02-01T03:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(37, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_85': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 43)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2016-01-30T03:00:00 ... 2016-02-04T09:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(43, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_86': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 51)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2016-02-03T21:00:00 ... 2016-02-10T03:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(51, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_87': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 49)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2016-12-19T06:00:00 ... 2016-12-25T06:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(49, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_88': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 67)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2016-12-21T03:00:00 ... 2016-12-29T09:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(67, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_89': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 111)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2017-10-04T03:00:00 ... 2017-10-17T21:00:00
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(111, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_90': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 0)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns]
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(0, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_91': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 0)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns]
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(0, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_92': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 0)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns]
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(0, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_93': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 0)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns]
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(0, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_94': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 0)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns]
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(0, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...,
#  'storm_95': <xarray.Dataset>
#  Dimensions:    (longitude: 1440, latitude: 721, time: 0)
#  Coordinates:
#    * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#    * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns]
#  Data variables:
#      d2m        (time, latitude, longitude) float32 dask.array<chunksize=(0, 721, 1440), meta=np.ndarray>
#  Attributes:
#      Conventions:  CF-1.6
#      history:      2023-10-13 21:02:30 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...}

# %%
# iterate through each time step

import dask.array as da

var_out = []

for j in range(0, 96):
    print(f"Processing track_{j}")
    for i in range(0, len(track_dict[f'track_{j}'])):
        print(f"  Processing index {i}")
        lon_e_temp, lon_w_temp, lat_s_temp, lat_n_temp = track_dict[f'track_{j}'].iloc[i]

        lon_test = np.asanyarray(d2m.longitude[:])
        lat_test = np.asanyarray(d2m.latitude[:])

        closest_lon_w = np.abs(lon_test - lon_w_temp).argmin()
        closest_lon_e = np.abs(lon_test - lon_e_temp).argmin()
        closest_lat_s = np.abs(lat_test - lat_s_temp).argmin()
        closest_lat_n = np.abs(lat_test - lat_n_temp).argmin()

        temp_ds = da.asarray(d2m['d2m'])

        var_out.append(temp_ds[i,closest_lat_n:closest_lat_s,closest_lon_e:closest_lon_w])
# Out:
# Processing track_0
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
#   Processing index 43
#   Processing index 44
#   Processing index 45
#   Processing index 46
#   Processing index 47
#   Processing index 48
#   Processing index 49
#   Processing index 50
#   Processing index 51
#   Processing index 52
#   Processing index 53
#   Processing index 54
#   Processing index 55
#   Processing index 56
#   Processing index 57
#   Processing index 58
#   Processing index 59
#   Processing index 60
#   Processing index 61
# Processing track_1
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
#   Processing index 43
#   Processing index 44
#   Processing index 45
#   Processing index 46
#   Processing index 47
#   Processing index 48
#   Processing index 49
#   Processing index 50
#   Processing index 51
# Processing track_2
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
#   Processing index 43
#   Processing index 44
#   Processing index 45
#   Processing index 46
#   Processing index 47
#   Processing index 48
#   Processing index 49
#   Processing index 50
#   Processing index 51
#   Processing index 52
#   Processing index 53
#   Processing index 54
#   Processing index 55
#   Processing index 56
#   Processing index 57
#   Processing index 58
# Processing track_3
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
# Processing track_4
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
# Processing track_5
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
#   Processing index 43
#   Processing index 44
#   Processing index 45
#   Processing index 46
#   Processing index 47
#   Processing index 48
#   Processing index 49
#   Processing index 50
#   Processing index 51
#   Processing index 52
#   Processing index 53
#   Processing index 54
#   Processing index 55
#   Processing index 56
#   Processing index 57
#   Processing index 58
#   Processing index 59
#   Processing index 60
#   Processing index 61
#   Processing index 62
#   Processing index 63
#   Processing index 64
#   Processing index 65
#   Processing index 66
#   Processing index 67
#   Processing index 68
#   Processing index 69
#   Processing index 70
#   Processing index 71
#   Processing index 72
#   Processing index 73
#   Processing index 74
#   Processing index 75
# Processing track_6
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
# Processing track_7
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
#   Processing index 43
#   Processing index 44
#   Processing index 45
#   Processing index 46
#   Processing index 47
#   Processing index 48
#   Processing index 49
#   Processing index 50
#   Processing index 51
#   Processing index 52
#   Processing index 53
#   Processing index 54
#   Processing index 55
#   Processing index 56
#   Processing index 57
#   Processing index 58
#   Processing index 59
#   Processing index 60
#   Processing index 61
#   Processing index 62
#   Processing index 63
#   Processing index 64
#   Processing index 65
#   Processing index 66
#   Processing index 67
#   Processing index 68
#   Processing index 69
#   Processing index 70
#   Processing index 71
#   Processing index 72
#   Processing index 73
#   Processing index 74
#   Processing index 75
#   Processing index 76
#   Processing index 77
#   Processing index 78
#   Processing index 79
#   Processing index 80
#   Processing index 81
#   Processing index 82
#   Processing index 83
#   Processing index 84
#   Processing index 85
#   Processing index 86
#   Processing index 87
#   Processing index 88
# Processing track_8
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
# Processing track_9
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
# Processing track_10
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
#   Processing index 43
#   Processing index 44
#   Processing index 45
#   Processing index 46
#   Processing index 47
#   Processing index 48
#   Processing index 49
#   Processing index 50
#   Processing index 51
#   Processing index 52
#   Processing index 53
#   Processing index 54
#   Processing index 55
#   Processing index 56
#   Processing index 57
#   Processing index 58
#   Processing index 59
#   Processing index 60
#   Processing index 61
#   Processing index 62
#   Processing index 63
#   Processing index 64
#   Processing index 65
#   Processing index 66
#   Processing index 67
#   Processing index 68
#   Processing index 69
#   Processing index 70
#   Processing index 71
#   Processing index 72
#   Processing index 73
#   Processing index 74
#   Processing index 75
#   Processing index 76
#   Processing index 77
#   Processing index 78
#   Processing index 79
#   Processing index 80
#   Processing index 81
#   Processing index 82
#   Processing index 83
#   Processing index 84
#   Processing index 85
#   Processing index 86
#   Processing index 87
#   Processing index 88
#   Processing index 89
#   Processing index 90
#   Processing index 91
#   Processing index 92
#   Processing index 93
#   Processing index 94
#   Processing index 95
#   Processing index 96
#   Processing index 97
#   Processing index 98
#   Processing index 99
#   Processing index 100
#   Processing index 101
#   Processing index 102
#   Processing index 103
#   Processing index 104
#   Processing index 105
#   Processing index 106
#   Processing index 107
#   Processing index 108
#   Processing index 109
#   Processing index 110
#   Processing index 111
# Processing track_11
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
#   Processing index 43
#   Processing index 44
#   Processing index 45
#   Processing index 46
#   Processing index 47
#   Processing index 48
# Processing track_12
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
#   Processing index 43
#   Processing index 44
#   Processing index 45
#   Processing index 46
#   Processing index 47
#   Processing index 48
#   Processing index 49
#   Processing index 50
#   Processing index 51
#   Processing index 52
#   Processing index 53
#   Processing index 54
#   Processing index 55
#   Processing index 56
# Processing track_13
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
#   Processing index 43
#   Processing index 44
#   Processing index 45
#   Processing index 46
#   Processing index 47
#   Processing index 48
#   Processing index 49
#   Processing index 50
#   Processing index 51
#   Processing index 52
#   Processing index 53
#   Processing index 54
#   Processing index 55
#   Processing index 56
#   Processing index 57
#   Processing index 58
#   Processing index 59
#   Processing index 60
#   Processing index 61
#   Processing index 62
#   Processing index 63
#   Processing index 64
#   Processing index 65
#   Processing index 66
#   Processing index 67
#   Processing index 68
#   Processing index 69
#   Processing index 70
#   Processing index 71
#   Processing index 72
#   Processing index 73
#   Processing index 74
#   Processing index 75
#   Processing index 76
#   Processing index 77
#   Processing index 78
#   Processing index 79
#   Processing index 80
#   Processing index 81
#   Processing index 82
#   Processing index 83
#   Processing index 84
#   Processing index 85
#   Processing index 86
#   Processing index 87
#   Processing index 88
#   Processing index 89
#   Processing index 90
#   Processing index 91
#   Processing index 92
#   Processing index 93
#   Processing index 94
#   Processing index 95
#   Processing index 96
#   Processing index 97
#   Processing index 98
#   Processing index 99
#   Processing index 100
# Processing track_14
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
#   Processing index 43
#   Processing index 44
#   Processing index 45
#   Processing index 46
#   Processing index 47
#   Processing index 48
#   Processing index 49
#   Processing index 50
#   Processing index 51
#   Processing index 52
#   Processing index 53
#   Processing index 54
#   Processing index 55
#   Processing index 56
# Processing track_15
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
#   Processing index 43
#   Processing index 44
#   Processing index 45
#   Processing index 46
#   Processing index 47
#   Processing index 48
#   Processing index 49
#   Processing index 50
#   Processing index 51
#   Processing index 52
#   Processing index 53
#   Processing index 54
#   Processing index 55
#   Processing index 56
#   Processing index 57
#   Processing index 58
#   Processing index 59
#   Processing index 60
#   Processing index 61
#   Processing index 62
#   Processing index 63
#   Processing index 64
#   Processing index 65
#   Processing index 66
#   Processing index 67
# Processing track_16
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
# Processing track_17
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
# Processing track_18
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
#   Processing index 43
#   Processing index 44
#   Processing index 45
#   Processing index 46
#   Processing index 47
#   Processing index 48
#   Processing index 49
#   Processing index 50
#   Processing index 51
#   Processing index 52
#   Processing index 53
#   Processing index 54
#   Processing index 55
#   Processing index 56
#   Processing index 57
#   Processing index 58
#   Processing index 59
#   Processing index 60
#   Processing index 61
#   Processing index 62
#   Processing index 63
#   Processing index 64
#   Processing index 65
#   Processing index 66
#   Processing index 67
#   Processing index 68
#   Processing index 69
#   Processing index 70
#   Processing index 71
#   Processing index 72
#   Processing index 73
#   Processing index 74
#   Processing index 75
# Processing track_19
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
# Processing track_20
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
#   Processing index 43
#   Processing index 44
#   Processing index 45
#   Processing index 46
#   Processing index 47
#   Processing index 48
#   Processing index 49
#   Processing index 50
#   Processing index 51
#   Processing index 52
#   Processing index 53
#   Processing index 54
#   Processing index 55
#   Processing index 56
#   Processing index 57
#   Processing index 58
#   Processing index 59
#   Processing index 60
#   Processing index 61
#   Processing index 62
#   Processing index 63
#   Processing index 64
#   Processing index 65
#   Processing index 66
#   Processing index 67
#   Processing index 68
#   Processing index 69
#   Processing index 70
#   Processing index 71
#   Processing index 72
#   Processing index 73
#   Processing index 74
#   Processing index 75
#   Processing index 76
#   Processing index 77
#   Processing index 78
#   Processing index 79
# Processing track_21
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
# Processing track_22
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
# Processing track_23
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
# Processing track_24
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
# Processing track_25
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
#   Processing index 43
#   Processing index 44
#   Processing index 45
#   Processing index 46
#   Processing index 47
#   Processing index 48
#   Processing index 49
#   Processing index 50
#   Processing index 51
#   Processing index 52
#   Processing index 53
#   Processing index 54
#   Processing index 55
#   Processing index 56
#   Processing index 57
#   Processing index 58
#   Processing index 59
#   Processing index 60
#   Processing index 61
#   Processing index 62
#   Processing index 63
#   Processing index 64
#   Processing index 65
#   Processing index 66
#   Processing index 67
#   Processing index 68
#   Processing index 69
#   Processing index 70
#   Processing index 71
#   Processing index 72
#   Processing index 73
#   Processing index 74
#   Processing index 75
# Processing track_26
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
#   Processing index 43
#   Processing index 44
#   Processing index 45
#   Processing index 46
#   Processing index 47
#   Processing index 48
#   Processing index 49
#   Processing index 50
#   Processing index 51
#   Processing index 52
#   Processing index 53
#   Processing index 54
#   Processing index 55
#   Processing index 56
#   Processing index 57
#   Processing index 58
#   Processing index 59
#   Processing index 60
#   Processing index 61
#   Processing index 62
#   Processing index 63
#   Processing index 64
#   Processing index 65
#   Processing index 66
#   Processing index 67
#   Processing index 68
#   Processing index 69
#   Processing index 70
#   Processing index 71
#   Processing index 72
#   Processing index 73
#   Processing index 74
#   Processing index 75
#   Processing index 76
#   Processing index 77
#   Processing index 78
#   Processing index 79
#   Processing index 80
#   Processing index 81
#   Processing index 82
#   Processing index 83
#   Processing index 84
#   Processing index 85
#   Processing index 86
#   Processing index 87
#   Processing index 88
#   Processing index 89
#   Processing index 90
#   Processing index 91
#   Processing index 92
#   Processing index 93
#   Processing index 94
#   Processing index 95
#   Processing index 96
#   Processing index 97
#   Processing index 98
#   Processing index 99
#   Processing index 100
#   Processing index 101
#   Processing index 102
#   Processing index 103
#   Processing index 104
#   Processing index 105
#   Processing index 106
#   Processing index 107
#   Processing index 108
#   Processing index 109
#   Processing index 110
#   Processing index 111
#   Processing index 112
#   Processing index 113
#   Processing index 114
#   Processing index 115
#   Processing index 116
#   Processing index 117
#   Processing index 118
#   Processing index 119
#   Processing index 120
#   Processing index 121
#   Processing index 122
#   Processing index 123
#   Processing index 124
#   Processing index 125
#   Processing index 126
#   Processing index 127
#   Processing index 128
#   Processing index 129
#   Processing index 130
#   Processing index 131
#   Processing index 132
#   Processing index 133
#   Processing index 134
#   Processing index 135
#   Processing index 136
#   Processing index 137
#   Processing index 138
#   Processing index 139
#   Processing index 140
#   Processing index 141
#   Processing index 142
#   Processing index 143
#   Processing index 144
#   Processing index 145
#   Processing index 146
#   Processing index 147
#   Processing index 148
#   Processing index 149
#   Processing index 150
#   Processing index 151
#   Processing index 152
#   Processing index 153
#   Processing index 154
#   Processing index 155
#   Processing index 156
#   Processing index 157
# Processing track_27
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
#   Processing index 43
#   Processing index 44
#   Processing index 45
#   Processing index 46
#   Processing index 47
#   Processing index 48
#   Processing index 49
#   Processing index 50
#   Processing index 51
#   Processing index 52
# Processing track_28
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
#   Processing index 43
#   Processing index 44
#   Processing index 45
#   Processing index 46
#   Processing index 47
#   Processing index 48
#   Processing index 49
#   Processing index 50
#   Processing index 51
#   Processing index 52
#   Processing index 53
#   Processing index 54
#   Processing index 55
#   Processing index 56
#   Processing index 57
#   Processing index 58
#   Processing index 59
#   Processing index 60
#   Processing index 61
#   Processing index 62
#   Processing index 63
#   Processing index 64
#   Processing index 65
#   Processing index 66
#   Processing index 67
#   Processing index 68
#   Processing index 69
# Processing track_29
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
#   Processing index 43
#   Processing index 44
#   Processing index 45
# Processing track_30
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
# Processing track_31
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
#   Processing index 43
#   Processing index 44
#   Processing index 45
#   Processing index 46
#   Processing index 47
#   Processing index 48
#   Processing index 49
# Processing track_32
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
#   Processing index 43
#   Processing index 44
# Processing track_33
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
#   Processing index 43
#   Processing index 44
#   Processing index 45
#   Processing index 46
# Processing track_34
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
#   Processing index 43
#   Processing index 44
#   Processing index 45
#   Processing index 46
# Processing track_35
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
# Processing track_36
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
# Processing track_37
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
# Processing track_38
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
#   Processing index 43
#   Processing index 44
#   Processing index 45
#   Processing index 46
#   Processing index 47
#   Processing index 48
#   Processing index 49
#   Processing index 50
#   Processing index 51
#   Processing index 52
#   Processing index 53
#   Processing index 54
#   Processing index 55
#   Processing index 56
#   Processing index 57
#   Processing index 58
#   Processing index 59
#   Processing index 60
# Processing track_39
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
#   Processing index 43
#   Processing index 44
#   Processing index 45
#   Processing index 46
#   Processing index 47
#   Processing index 48
#   Processing index 49
#   Processing index 50
#   Processing index 51
# Processing track_40
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
# Processing track_41
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
# Processing track_42
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
# ...
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
# Processing track_81
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
#   Processing index 43
# Processing track_82
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
#   Processing index 43
#   Processing index 44
#   Processing index 45
#   Processing index 46
#   Processing index 47
#   Processing index 48
#   Processing index 49
#   Processing index 50
#   Processing index 51
#   Processing index 52
#   Processing index 53
# Processing track_83
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
# Processing track_84
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
# Processing track_85
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
# Processing track_86
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
#   Processing index 43
#   Processing index 44
#   Processing index 45
#   Processing index 46
#   Processing index 47
#   Processing index 48
#   Processing index 49
#   Processing index 50
# Processing track_87
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
#   Processing index 43
#   Processing index 44
#   Processing index 45
#   Processing index 46
#   Processing index 47
#   Processing index 48
# Processing track_88
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
#   Processing index 43
#   Processing index 44
#   Processing index 45
#   Processing index 46
#   Processing index 47
#   Processing index 48
#   Processing index 49
#   Processing index 50
#   Processing index 51
#   Processing index 52
#   Processing index 53
#   Processing index 54
#   Processing index 55
#   Processing index 56
#   Processing index 57
#   Processing index 58
#   Processing index 59
#   Processing index 60
#   Processing index 61
#   Processing index 62
#   Processing index 63
#   Processing index 64
#   Processing index 65
#   Processing index 66
# Processing track_89
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
#   Processing index 43
#   Processing index 44
#   Processing index 45
#   Processing index 46
#   Processing index 47
#   Processing index 48
#   Processing index 49
#   Processing index 50
#   Processing index 51
#   Processing index 52
#   Processing index 53
#   Processing index 54
#   Processing index 55
#   Processing index 56
#   Processing index 57
#   Processing index 58
#   Processing index 59
#   Processing index 60
#   Processing index 61
#   Processing index 62
#   Processing index 63
#   Processing index 64
#   Processing index 65
#   Processing index 66
#   Processing index 67
#   Processing index 68
#   Processing index 69
#   Processing index 70
#   Processing index 71
#   Processing index 72
#   Processing index 73
#   Processing index 74
#   Processing index 75
#   Processing index 76
#   Processing index 77
#   Processing index 78
#   Processing index 79
#   Processing index 80
#   Processing index 81
#   Processing index 82
#   Processing index 83
#   Processing index 84
#   Processing index 85
#   Processing index 86
#   Processing index 87
#   Processing index 88
#   Processing index 89
#   Processing index 90
#   Processing index 91
#   Processing index 92
#   Processing index 93
#   Processing index 94
#   Processing index 95
#   Processing index 96
#   Processing index 97
#   Processing index 98
#   Processing index 99
#   Processing index 100
#   Processing index 101
#   Processing index 102
#   Processing index 103
#   Processing index 104
#   Processing index 105
#   Processing index 106
#   Processing index 107
#   Processing index 108
#   Processing index 109
#   Processing index 110
# Processing track_90
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
# Processing track_91
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
# Processing track_92
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
# Processing track_93
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
#   Processing index 43
#   Processing index 44
#   Processing index 45
#   Processing index 46
#   Processing index 47
#   Processing index 48
# Processing track_94
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27
#   Processing index 28
#   Processing index 29
#   Processing index 30
#   Processing index 31
#   Processing index 32
#   Processing index 33
#   Processing index 34
#   Processing index 35
#   Processing index 36
#   Processing index 37
#   Processing index 38
#   Processing index 39
#   Processing index 40
#   Processing index 41
#   Processing index 42
#   Processing index 43
#   Processing index 44
#   Processing index 45
#   Processing index 46
#   Processing index 47
#   Processing index 48
#   Processing index 49
# Processing track_95
#   Processing index 0
#   Processing index 1
#   Processing index 2
#   Processing index 3
#   Processing index 4
#   Processing index 5
#   Processing index 6
#   Processing index 7
#   Processing index 8
#   Processing index 9
#   Processing index 10
#   Processing index 11
#   Processing index 12
#   Processing index 13
#   Processing index 14
#   Processing index 15
#   Processing index 16
#   Processing index 17
#   Processing index 18
#   Processing index 19
#   Processing index 20
#   Processing index 21
#   Processing index 22
#   Processing index 23
#   Processing index 24
#   Processing index 25
#   Processing index 26
#   Processing index 27

# %%
# check if each square has the same shape

for i in range(0, len(var_out)):
    #print(var_out[i].shape)
    if var_out[i].shape != (32,32):
        print(f"Shape of index {i} is {var_out[i].shape}")

        # not every square is square so to check next time :(
# Out:
# Shape of index 81 is (32, 26)
# Shape of index 82 is (32, 0)
# Shape of index 83 is (32, 0)
# Shape of index 156 is (32, 31)
# Shape of index 157 is (32, 29)
# Shape of index 158 is (32, 27)
# Shape of index 159 is (32, 27)
# Shape of index 160 is (32, 25)
# Shape of index 161 is (32, 23)
# Shape of index 162 is (32, 22)
# Shape of index 163 is (32, 19)
# Shape of index 164 is (32, 0)
# Shape of index 165 is (32, 0)
# Shape of index 166 is (32, 0)
# Shape of index 167 is (32, 0)
# Shape of index 168 is (32, 0)
# Shape of index 188 is (32, 28)
# Shape of index 209 is (32, 23)
# Shape of index 210 is (32, 0)
# Shape of index 278 is (32, 30)
# Shape of index 279 is (32, 15)
# Shape of index 280 is (32, 0)
# Shape of index 325 is (32, 28)
# Shape of index 326 is (32, 17)
# Shape of index 327 is (32, 0)
# Shape of index 372 is (32, 31)
# Shape of index 373 is (32, 21)
# Shape of index 374 is (32, 0)
# Shape of index 375 is (32, 0)
# Shape of index 427 is (29, 32)
# Shape of index 428 is (28, 32)
# Shape of index 429 is (28, 32)
# Shape of index 430 is (27, 32)
# Shape of index 431 is (27, 32)
# Shape of index 432 is (27, 32)
# Shape of index 433 is (27, 32)
# Shape of index 434 is (27, 32)
# Shape of index 435 is (27, 32)
# Shape of index 436 is (27, 32)
# Shape of index 437 is (27, 32)
# Shape of index 445 is (32, 25)
# Shape of index 446 is (32, 18)
# Shape of index 447 is (32, 0)
# Shape of index 448 is (32, 0)
# Shape of index 475 is (32, 28)
# Shape of index 476 is (32, 0)
# Shape of index 535 is (32, 30)
# Shape of index 536 is (32, 24)
# Shape of index 537 is (32, 15)
# Shape of index 538 is (32, 0)
# Shape of index 639 is (32, 31)
# Shape of index 640 is (32, 22)
# Shape of index 641 is (32, 0)
# Shape of index 642 is (32, 0)
# Shape of index 684 is (32, 22)
# Shape of index 685 is (32, 0)
# Shape of index 754 is (32, 27)
# Shape of index 755 is (32, 23)
# Shape of index 756 is (32, 18)
# Shape of index 757 is (32, 16)
# Shape of index 758 is (32, 0)
# Shape of index 759 is (32, 0)
# Shape of index 760 is (32, 0)
# Shape of index 854 is (32, 31)
# Shape of index 855 is (32, 28)
# Shape of index 856 is (32, 26)
# Shape of index 857 is (32, 23)
# Shape of index 858 is (32, 21)
# Shape of index 859 is (32, 18)
# Shape of index 860 is (32, 16)
# Shape of index 861 is (32, 0)
# Shape of index 862 is (32, 0)
# Shape of index 863 is (32, 0)
# Shape of index 864 is (32, 0)
# Shape of index 865 is (32, 0)
# Shape of index 866 is (32, 15)
# Shape of index 867 is (32, 18)
# Shape of index 868 is (32, 20)
# Shape of index 869 is (32, 21)
# Shape of index 870 is (32, 20)
# Shape of index 871 is (32, 16)
# Shape of index 872 is (32, 0)
# Shape of index 873 is (32, 0)
# Shape of index 874 is (32, 0)
# Shape of index 904 is (32, 27)
# Shape of index 905 is (32, 17)
# Shape of index 906 is (32, 0)
# Shape of index 907 is (32, 0)
# Shape of index 908 is (32, 0)
# Shape of index 909 is (32, 0)
# Shape of index 959 is (32, 26)
# Shape of index 960 is (32, 0)
# Shape of index 988 is (32, 18)
# Shape of index 989 is (32, 0)
# Shape of index 1043 is (32, 26)
# Shape of index 1044 is (32, 0)
# Shape of index 1045 is (32, 0)
# Shape of index 1085 is (32, 23)
# Shape of index 1086 is (32, 0)
# Shape of index 1149 is (32, 29)
# Shape of index 1150 is (32, 23)
# Shape of index 1151 is (32, 0)
# Shape of index 1152 is (32, 0)
# Shape of index 1200 is (32, 23)
# Shape of index 1201 is (32, 0)
# Shape of index 1202 is (32, 0)
# Shape of index 1203 is (32, 0)
# Shape of index 1204 is (32, 0)
# Shape of index 1205 is (32, 0)
# Shape of index 1206 is (32, 0)
# Shape of index 1207 is (32, 18)
# Shape of index 1208 is (32, 21)
# Shape of index 1209 is (32, 24)
# Shape of index 1210 is (32, 21)
# Shape of index 1211 is (32, 20)
# Shape of index 1212 is (32, 21)
# Shape of index 1213 is (32, 22)
# Shape of index 1214 is (32, 24)
# Shape of index 1215 is (32, 26)
# Shape of index 1216 is (32, 28)
# Shape of index 1217 is (32, 26)
# Shape of index 1218 is (32, 21)
# Shape of index 1219 is (32, 15)
# Shape of index 1220 is (32, 0)
# Shape of index 1221 is (32, 0)
# Shape of index 1270 is (32, 29)
# Shape of index 1314 is (32, 27)
# Shape of index 1315 is (32, 16)
# Shape of index 1316 is (32, 0)
# Shape of index 1482 is (32, 24)
# Shape of index 1483 is (32, 16)
# Shape of index 1484 is (32, 0)
# Shape of index 1511 is (32, 24)
# Shape of index 1512 is (32, 0)
# Shape of index 1618 is (32, 30)
# Shape of index 1619 is (32, 0)
# Shape of index 1635 is (32, 30)
# Shape of index 1636 is (32, 18)
# Shape of index 1637 is (32, 0)
# Shape of index 1691 is (32, 22)
# Shape of index 1692 is (32, 0)
# Shape of index 1693 is (32, 0)
# Shape of index 1736 is (32, 25)
# Shape of index 1737 is (32, 17)
# Shape of index 1738 is (32, 0)
# Shape of index 1739 is (32, 0)
# Shape of index 1817 is (32, 29)
# Shape of index 1818 is (32, 18)
# Shape of index 1819 is (32, 0)
# Shape of index 1875 is (32, 28)
# Shape of index 1876 is (32, 24)
# Shape of index 1877 is (32, 21)
# Shape of index 1878 is (32, 16)
# Shape of index 1879 is (32, 0)
# Shape of index 1880 is (32, 0)
# Shape of index 1881 is (32, 0)
# Shape of index 1920 is (32, 17)
# Shape of index 1921 is (32, 0)
# Shape of index 1964 is (32, 31)
# Shape of index 1965 is (32, 0)
# Shape of index 1966 is (32, 0)
# Shape of index 1993 is (32, 27)
# Shape of index 1994 is (32, 17)
# Shape of index 1995 is (32, 0)
# Shape of index 2042 is (32, 21)
# Shape of index 2043 is (32, 0)
# Shape of index 2090 is (32, 31)
# Shape of index 2091 is (32, 28)
# Shape of index 2092 is (32, 22)
# Shape of index 2093 is (32, 18)
# Shape of index 2094 is (32, 16)
# Shape of index 2095 is (32, 0)
# Shape of index 2096 is (32, 0)
# Shape of index 2097 is (32, 16)
# Shape of index 2098 is (32, 21)
# Shape of index 2103 is (32, 30)
# Shape of index 2104 is (32, 19)
# Shape of index 2105 is (32, 0)
# Shape of index 2106 is (32, 0)
# Shape of index 2116 is (32, 0)
# Shape of index 2117 is (32, 0)
# Shape of index 2118 is (32, 0)
# Shape of index 2119 is (32, 0)
# Shape of index 2120 is (32, 21)
# Shape of index 2121 is (32, 26)
# Shape of index 2122 is (32, 29)
# Shape of index 2155 is (32, 26)
# Shape of index 2156 is (32, 0)
# Shape of index 2157 is (32, 0)
# Shape of index 2200 is (32, 27)
# Shape of index 2201 is (32, 0)
# Shape of index 2281 is (32, 15)
# Shape of index 2282 is (32, 0)
# Shape of index 2352 is (32, 25)
# Shape of index 2353 is (32, 0)
# Shape of index 2354 is (32, 0)
# Shape of index 2405 is (32, 23)
# Shape of index 2406 is (32, 0)
# Shape of index 2471 is (32, 31)
# Shape of index 2472 is (32, 23)
# Shape of index 2473 is (32, 0)
# Shape of index 2474 is (32, 0)
# Shape of index 2572 is (32, 27)
# Shape of index 2573 is (32, 20)
# Shape of index 2574 is (32, 15)
# Shape of index 2575 is (32, 0)
# Shape of index 2576 is (32, 0)
# Shape of index 2577 is (32, 0)
# Shape of index 2578 is (32, 0)
# Shape of index 2641 is (32, 28)
# Shape of index 2642 is (32, 23)
# Shape of index 2643 is (32, 19)
# Shape of index 2644 is (32, 0)
# Shape of index 2645 is (32, 0)
# Shape of index 2646 is (32, 0)
# Shape of index 2678 is (32, 23)
# Shape of index 2679 is (32, 0)
# Shape of index 2680 is (32, 0)
# Shape of index 2738 is (32, 31)
# Shape of index 2739 is (32, 18)
# Shape of index 2740 is (32, 0)
# Shape of index 2786 is (32, 30)
# Shape of index 2787 is (32, 16)
# Shape of index 2788 is (32, 0)
# Shape of index 2837 is (32, 30)
# Shape of index 2838 is (32, 0)
# Shape of index 2873 is (32, 21)
# Shape of index 2874 is (32, 0)
# Shape of index 2945 is (32, 28)
# Shape of index 2946 is (32, 22)
# Shape of index 2947 is (32, 17)
# Shape of index 2948 is (32, 0)
# Shape of index 2949 is (32, 0)
# Shape of index 2950 is (32, 0)
# Shape of index 2951 is (32, 0)
# Shape of index 2967 is (32, 29)
# Shape of index 2968 is (32, 25)
# Shape of index 2969 is (32, 20)
# Shape of index 2970 is (32, 17)
# Shape of index 2971 is (32, 0)
# Shape of index 2972 is (32, 0)
# Shape of index 2973 is (32, 0)
# Shape of index 2974 is (32, 0)
# Shape of index 3021 is (32, 23)
# Shape of index 3022 is (32, 0)
# Shape of index 3073 is (32, 0)
# Shape of index 3114 is (32, 21)
# Shape of index 3115 is (32, 0)
# Shape of index 3189 is (32, 30)
# Shape of index 3190 is (32, 20)
# Shape of index 3191 is (32, 0)
# Shape of index 3243 is (32, 24)
# Shape of index 3244 is (32, 0)
# Shape of index 3326 is (32, 31)
# Shape of index 3327 is (32, 19)
# Shape of index 3328 is (32, 0)
# Shape of index 3395 is (32, 28)
# Shape of index 3396 is (32, 22)
# Shape of index 3397 is (32, 16)
# Shape of index 3398 is (32, 0)
# Shape of index 3399 is (32, 0)
# Shape of index 3474 is (32, 29)
# Shape of index 3475 is (32, 19)
# Shape of index 3476 is (32, 0)
# Shape of index 3477 is (32, 0)
# Shape of index 3478 is (32, 0)
# Shape of index 3479 is (32, 0)
# Shape of index 3480 is (32, 0)
# Shape of index 3481 is (32, 0)
# Shape of index 3482 is (32, 0)
# Shape of index 3483 is (32, 0)
# Shape of index 3504 is (32, 29)
# Shape of index 3505 is (32, 21)
# Shape of index 3506 is (32, 0)
# Shape of index 3507 is (32, 0)
# Shape of index 3547 is (32, 27)
# Shape of index 3548 is (32, 16)
# Shape of index 3549 is (32, 0)
# Shape of index 3613 is (32, 30)
# Shape of index 3614 is (32, 0)
# Shape of index 3630 is (32, 24)
# Shape of index 3631 is (32, 0)
# Shape of index 3682 is (32, 21)
# Shape of index 3683 is (32, 0)
# Shape of index 3736 is (32, 25)
# Shape of index 3737 is (32, 0)
# Shape of index 3784 is (32, 30)
# Shape of index 3785 is (32, 0)
# Shape of index 3837 is (32, 31)
# Shape of index 3838 is (32, 28)
# Shape of index 3839 is (32, 28)
# Shape of index 3840 is (32, 27)
# Shape of index 3841 is (32, 28)
# Shape of index 3842 is (32, 31)
# Shape of index 3871 is (32, 27)
# Shape of index 3872 is (32, 19)
# Shape of index 3873 is (32, 16)
# Shape of index 3874 is (32, 15)
# Shape of index 3875 is (32, 19)
# Shape of index 3876 is (32, 18)
# Shape of index 3877 is (32, 0)
# Shape of index 3878 is (32, 0)
# Shape of index 3879 is (32, 0)
# Shape of index 3880 is (32, 0)
# Shape of index 3881 is (32, 0)
# Shape of index 3882 is (32, 0)
# Shape of index 3883 is (32, 0)
# Shape of index 3884 is (32, 0)
# Shape of index 3885 is (32, 0)
# Shape of index 3886 is (32, 0)
# Shape of index 3887 is (32, 20)
# Shape of index 3888 is (32, 27)
# Shape of index 3952 is (32, 26)
# Shape of index 3953 is (32, 0)
# Shape of index 4018 is (32, 31)
# Shape of index 4019 is (32, 27)
# Shape of index 4020 is (32, 24)
# Shape of index 4021 is (32, 21)
# Shape of index 4022 is (32, 19)
# Shape of index 4023 is (32, 16)
# Shape of index 4024 is (32, 0)
# Shape of index 4025 is (32, 0)
# Shape of index 4026 is (32, 0)
# Shape of index 4027 is (32, 0)
# Shape of index 4028 is (32, 0)
# Shape of index 4069 is (32, 28)
# Shape of index 4070 is (32, 21)
# Shape of index 4071 is (32, 17)
# Shape of index 4072 is (32, 15)
# Shape of index 4073 is (32, 0)
# Shape of index 4074 is (32, 16)
# Shape of index 4075 is (32, 18)
# Shape of index 4076 is (32, 18)
# Shape of index 4077 is (32, 17)
# Shape of index 4078 is (32, 17)
# Shape of index 4079 is (32, 0)
# Shape of index 4080 is (32, 0)
# Shape of index 4081 is (32, 0)
# Shape of index 4082 is (32, 0)
# Shape of index 4083 is (32, 0)
# Shape of index 4084 is (32, 0)
# Shape of index 4085 is (32, 0)
# Shape of index 4086 is (32, 0)
# Shape of index 4087 is (32, 15)
# Shape of index 4130 is (32, 17)
# Shape of index 4131 is (32, 0)
# Shape of index 4178 is (32, 0)
# Shape of index 4208 is (32, 27)
# Shape of index 4209 is (32, 18)
# Shape of index 4210 is (32, 0)
# Shape of index 4211 is (32, 0)
# Shape of index 4212 is (32, 0)
# Shape of index 4213 is (32, 0)
# Shape of index 4225 is (32, 0)
# Shape of index 4226 is (32, 0)
# Shape of index 4227 is (32, 0)
# Shape of index 4228 is (32, 16)
# Shape of index 4229 is (32, 21)
# Shape of index 4230 is (32, 29)
# Shape of index 4260 is (32, 28)
# Shape of index 4261 is (32, 22)
# Shape of index 4262 is (32, 16)
# Shape of index 4263 is (32, 0)
# Shape of index 4264 is (32, 0)
# Shape of index 4265 is (32, 0)
# Shape of index 4287 is (32, 0)
# Shape of index 4291 is (32, 19)
# Shape of index 4319 is (27, 32)
# Shape of index 4334 is (32, 30)
# Shape of index 4335 is (32, 0)
# Shape of index 4336 is (32, 0)
# Shape of index 4346 is (32, 0)
# Shape of index 4347 is (32, 0)
# Shape of index 4348 is (32, 16)
# Shape of index 4349 is (32, 20)
# Shape of index 4350 is (32, 22)
# Shape of index 4351 is (32, 22)
# Shape of index 4352 is (32, 21)
# Shape of index 4353 is (32, 19)
# Shape of index 4354 is (32, 0)
# Shape of index 4355 is (32, 0)
# Shape of index 4381 is (32, 28)
# Shape of index 4382 is (32, 17)
# Shape of index 4383 is (32, 0)
# Shape of index 4384 is (32, 0)
# Shape of index 4437 is (32, 19)
# Shape of index 4438 is (32, 0)
# Shape of index 4439 is (32, 0)
# Shape of index 4494 is (32, 25)
# Shape of index 4495 is (32, 16)
# Shape of index 4496 is (32, 0)
# Shape of index 4541 is (32, 29)
# Shape of index 4542 is (32, 20)
# Shape of index 4543 is (32, 0)
# Shape of index 4671 is (32, 29)
# Shape of index 4672 is (32, 22)
# Shape of index 4673 is (32, 0)
# Shape of index 4674 is (32, 0)
# Shape of index 4675 is (32, 0)
# Shape of index 4703 is (32, 25)
# Shape of index 4704 is (32, 0)
# Shape of index 4757 is (32, 29)
# Shape of index 4758 is (32, 16)
# Shape of index 4759 is (32, 0)
# Shape of index 4760 is (32, 0)
# Shape of index 4773 is (32, 30)
# Shape of index 4774 is (32, 28)
# Shape of index 4775 is (32, 26)
# Shape of index 4776 is (32, 25)
# Shape of index 4777 is (32, 23)
# Shape of index 4778 is (32, 22)
# Shape of index 4779 is (32, 19)
# Shape of index 4780 is (32, 17)
# Shape of index 4781 is (32, 16)
# Shape of index 4782 is (32, 16)
# Shape of index 4783 is (32, 18)
# Shape of index 4784 is (32, 17)
# Shape of index 4785 is (32, 0)
# Shape of index 4786 is (32, 17)
# Shape of index 4787 is (32, 18)
# Shape of index 4788 is (32, 19)
# Shape of index 4789 is (32, 21)
# Shape of index 4790 is (32, 23)
# Shape of index 4791 is (32, 25)
# Shape of index 4792 is (32, 25)
# Shape of index 4793 is (32, 23)
# Shape of index 4794 is (32, 21)
# Shape of index 4795 is (32, 19)
# Shape of index 4796 is (32, 16)
# Shape of index 4797 is (32, 0)
# Shape of index 4798 is (32, 0)
# Shape of index 4799 is (32, 0)
# Shape of index 4800 is (32, 0)
# Shape of index 4801 is (32, 0)
# Shape of index 4802 is (32, 0)
# Shape of index 4803 is (32, 0)
# Shape of index 4804 is (32, 20)
# Shape of index 4805 is (32, 23)
# Shape of index 4806 is (32, 19)
# Shape of index 4807 is (32, 16)
# Shape of index 4808 is (32, 0)
# Shape of index 4809 is (32, 0)
# Shape of index 4810 is (32, 0)
# Shape of index 4854 is (32, 30)
# Shape of index 4855 is (32, 17)
# Shape of index 4856 is (32, 0)
# Shape of index 4857 is (32, 0)
# Shape of index 4858 is (32, 0)
# Shape of index 4881 is (32, 24)
# Shape of index 4882 is (32, 0)
# Shape of index 4883 is (32, 0)

# %%
bug = var_out[446]

bug = bug.compute()

# %%
# check the coordinates of var_out that are not 32x32

for i in range(0, len(var_out)):
    if var_out[i].shape != (32,32):
        print(f"Coordinates of index {i} are {track_dict[f'track_{i}'].iloc[i]}")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[26], line 5
#       3 for i in range(0, len(var_out)):
#       4     if var_out[i].shape != (32,32):
# ----> 5         print(f"Coordinates of index {i} are {track_dict[f'track_{i}'].iloc[i]}")
#
# File ~/miniconda3/envs/kera_lgbm/lib/python3.9/site-packages/pandas/core/indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/miniconda3/envs/kera_lgbm/lib/python3.9/site-packages/pandas/core/indexing.py:1656, in _iLocIndexer._getitem_axis(self, key, axis)
#    1653     raise TypeError("Cannot index by location index with a non-integer key")
#    1655 # validate the location
# -> 1656 self._validate_integer(key, axis)
#    1658 return self.obj._ixs(key, axis=axis)
#
# File ~/miniconda3/envs/kera_lgbm/lib/python3.9/site-packages/pandas/core/indexing.py:1589, in _iLocIndexer._validate_integer(self, key, axis)
#    1587 len_axis = len(self.obj._get_axis(axis))
#    1588 if key >= len_axis or key < -len_axis:
# -> 1589     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %%
# convert from dask array to numpy array

var_out_np = []

for i in range(0, len(var_out)):
    var_out_np.append(var_out[i].compute())

# %%
# Check if any array is empty
np.isnan(var_out_np)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 2
#       1 # Check if any array is empty
# ----> 2 np.isnan(var_out_np)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (4890,) + inhomogeneous part.

# %%
# mean, min, max value of each time step

mean_out_d2m = []
min_out_d2m = []
max_out_d2m = []

for i in range(0, len(var_out_np)):
    mean_out_d2m.append(np.mean(var_out_np[i]))
    min_out_d2m.append(np.min(var_out_np[i]))
    max_out_d2m.append(np.max(var_out_np[i]))
# Out:
# /users/faugsbur/miniconda3/envs/kera_lgbm/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /users/faugsbur/miniconda3/envs/kera_lgbm/lib/python3.9/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 9
#       7 for i in range(0, len(var_out_np)):
#       8     mean_out_d2m.append(np.mean(var_out_np[i]))
# ----> 9     min_out_d2m.append(np.min(var_out_np[i]))
#      10     max_out_d2m.append(np.max(var_out_np[i]))
#
# File <__array_function__ internals>:200, in amin(*args, **kwargs)
#
# File ~/miniconda3/envs/kera_lgbm/lib/python3.9/site-packages/numpy/core/fromnumeric.py:2946, in amin(a, axis, out, keepdims, initial, where)
#    2829 @array_function_dispatch(_amin_dispatcher)
#    2830 def amin(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2831          where=np._NoValue):
#    2832     """
#    2833     Return the minimum of an array or minimum along an axis.
#    2834
#    (...)
#    2944     6
#    2945     """
# -> 2946     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#    2947                           keepdims=keepdims, initial=initial, where=where)
#
# File ~/miniconda3/envs/kera_lgbm/lib/python3.9/site-packages/numpy/core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
# save as csv

df_mean = pd.DataFrame(mean_out_d2m)
df_min = pd.DataFrame(min_out_d2m)
df_max = pd.DataFrame(max_out_d2m)

df_mean.to_csv('d2m_mean.csv')
df_min.to_csv('d2m_min.csv')
df_max.to_csv('d2m_max.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 4
#       1 # save as csv
#       3 df_mean = pd.DataFrame(mean_out_d2m)
# ----> 4 df_min = pd.DataFrame(min_out_d2m)
#       5 df_max = pd.DataFrame(max_out_d2m)
#       7 df_mean.to_csv('d2m_mean.csv')
#
# File ~/miniconda3/envs/kera_lgbm/lib/python3.9/site-packages/pandas/core/frame.py:798, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     790         mgr = arrays_to_mgr(
#     791             arrays,
#     792             columns,
#    (...)
#     795             typ=manager,
#     796         )
#     797     else:
# --> 798         mgr = ndarray_to_mgr(
#     799             data,
#     800             index,
#     801             columns,
#     802             dtype=dtype,
#     803             copy=copy,
#     804             typ=manager,
#     805         )
#     806 else:
#     807     mgr = dict_to_mgr(
#     808         {},
#     809         index,
#    (...)
#     812         typ=manager,
#     813     )
#
# File ~/miniconda3/envs/kera_lgbm/lib/python3.9/site-packages/pandas/core/internals/construction.py:320, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     315     values = _ensure_2d(values)
#     317 else:
#     318     # by definition an array here
#     319     # the dtypes will be coerced to a single dtype
# --> 320     values = _prep_ndarraylike(values, copy=copy_on_sanitize)
#     322 if dtype is not None and not is_dtype_equal(values.dtype, dtype):
#     323     # GH#40110 see similar check inside sanitize_array
#     324     values = sanitize_array(
#     325         values,
#     326         None,
#    (...)
#     329         allow_2d=True,
#     330     )
#
# File ~/miniconda3/envs/kera_lgbm/lib/python3.9/site-packages/pandas/core/internals/construction.py:558, in _prep_ndarraylike(values, copy)
#     556     values = np.array([convert(v) for v in values])
#     557 else:
# --> 558     values = convert(values)
#     560 return _ensure_2d(values)
#
# File ~/miniconda3/envs/kera_lgbm/lib/python3.9/site-packages/pandas/core/internals/construction.py:542, in _prep_ndarraylike.<locals>.convert(v)
#     539     return v
#     541 v = extract_array(v, extract_numpy=True)
# --> 542 res = maybe_convert_platform(v)
#     543 # We don't do maybe_infer_to_datetimelike here bc we will end up doing
#     544 #  it column-by-column in ndarray_to_mgr
#     545 return res
#
# File ~/miniconda3/envs/kera_lgbm/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:128, in maybe_convert_platform(values)
#     125 arr: ArrayLike
#     127 if isinstance(values, (list, tuple, range)):
# --> 128     arr = construct_1d_object_array_from_listlike(values)
#     129 else:
#     130     # The caller is responsible for ensuring that we have np.ndarray
#     131     #  or ExtensionArray here.
#     132     arr = values
#
# File ~/miniconda3/envs/kera_lgbm/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:1542, in construct_1d_object_array_from_listlike(values)
#    1539 # numpy will try to interpret nested lists as further dimensions, hence
#    1540 # making a 1D array that contains list-likes is a bit tricky:
#    1541 result = np.empty(len(values), dtype="object")
# -> 1542 result[:] = values
#    1543 return result
#
# File ~/miniconda3/envs/kera_lgbm/lib/python3.9/site-packages/dask/array/core.py:1701, in Array.__array__(self, dtype, **kwargs)
#    1700 def __array__(self, dtype=None, **kwargs):
# -> 1701     x = self.compute()
#    1702     if dtype and x.dtype != dtype:
#    1703         x = x.astype(dtype)
#
# File ~/miniconda3/envs/kera_lgbm/lib/python3.9/site-packages/dask/base.py:314, in DaskMethodsMixin.compute(self, **kwargs)
#     290 def compute(self, **kwargs):
#     291     """Compute this dask collection
#     292
#     293     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     312     dask.compute
#     313     """
# --> 314     (result,) = compute(self, traverse=False, **kwargs)
#     315     return result
#
# File ~/miniconda3/envs/kera_lgbm/lib/python3.9/site-packages/dask/base.py:599, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     596     keys.append(x.__dask_keys__())
#     597     postcomputes.append(x.__dask_postcompute__())
# --> 599 results = schedule(dsk, keys, **kwargs)
#     600 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/miniconda3/envs/kera_lgbm/lib/python3.9/site-packages/dask/threaded.py:89, in get(dsk, keys, cache, num_workers, pool, **kwargs)
#      86     elif isinstance(pool, multiprocessing.pool.Pool):
#      87         pool = MultiprocessingPoolExecutor(pool)
# ---> 89 results = get_async(
#      90     pool.submit,
#      91     pool._max_workers,
#      92     dsk,
#      93     keys,
#      94     cache=cache,
#      95     get_id=_thread_get_id,
#      96     pack_exception=pack_exception,
#      97     **kwargs,
#      98 )
#     100 # Cleanup pools associated to dead threads
#     101 with pools_lock:
#
# File ~/miniconda3/envs/kera_lgbm/lib/python3.9/site-packages/dask/local.py:511, in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     509         _execute_task(task, data)  # Re-execute locally
#     510     else:
# --> 511         raise_exception(exc, tb)
#     512 res, worker_id = loads(res_info)
#     513 state["cache"][key] = res
#
# File ~/miniconda3/envs/kera_lgbm/lib/python3.9/site-packages/dask/local.py:319, in reraise(exc, tb)
#     317 if exc.__traceback__ is not tb:
#     318     raise exc.with_traceback(tb)
# --> 319 raise exc
#
# File ~/miniconda3/envs/kera_lgbm/lib/python3.9/site-packages/dask/local.py:224, in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     222 try:
#     223     task, data = loads(task_info)
# --> 224     result = _execute_task(task, data)
#     225     id = get_id()
#     226     result = dumps((result, id))
#
# File ~/miniconda3/envs/kera_lgbm/lib/python3.9/site-packages/dask/core.py:119, in _execute_task(arg, cache, dsk)
#     115     func, args = arg[0], arg[1:]
#     116     # Note: Don't assign the subtask results to a variable. numpy detects
#     117     # temporaries by their reference count and can execute certain
#     118     # operations in-place.
# --> 119     return func(*(_execute_task(a, cache) for a in args))
#     120 elif not ishashable(arg):
#     121     return arg
#
# File ~/miniconda3/envs/kera_lgbm/lib/python3.9/site-packages/cytoolz/functoolz.pyx:504, in cytoolz.functoolz.Compose.__call__()
#
# File <__array_function__ internals>:200, in amin(*args, **kwargs)
#
# File ~/miniconda3/envs/kera_lgbm/lib/python3.9/site-packages/numpy/core/fromnumeric.py:2946, in amin(a, axis, out, keepdims, initial, where)
#    2829 @array_function_dispatch(_amin_dispatcher)
#    2830 def amin(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2831          where=np._NoValue):
#    2832     """
#    2833     Return the minimum of an array or minimum along an axis.
#    2834
#    (...)
#    2944     6
#    2945     """
# -> 2946     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#    2947                           keepdims=keepdims, initial=initial, where=where)
#
# File ~/miniconda3/envs/kera_lgbm/lib/python3.9/site-packages/numpy/core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %% [markdown]
# For all variables, (class by variable (folder), then by storm))
